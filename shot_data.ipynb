# %%
import pandas as pd
import requests
import json

# %%
# Harden, 2018-19
url_base = 'https://stats.nba.com/stats/shotchartdetail'

headers = {
    'Host': 'stats.nba.com',
    'Connection': 'keep-alive',
    'Accept': 'application/json, text/plain, */*',
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/79.0.3945.130 Safari/537.36',
    'Referer': 'https://stats.nba.com/',
    "x-nba-stats-origin": "stats",
    "x-nba-stats-token": "true",
    'Accept-Encoding': 'gzip, deflate, br',
    'Accept-Language': 'en-US,en;q=0.9',
}

# %%
parameters = {
    'ContextMeasure': 'FGA',
    'LastNGames': 0,
    'LeagueID': '00',
    'Month': 0,
    'OpponentTeamID': 0,
    'Period': 0,
    'PlayerID': 201935,
    'SeasonType': 'Regular Season',
    'TeamID': 0,
    'VsDivision': '',
    'VsConference': '',
    'SeasonSegment': '',
    'Season': '2018-19',
    'RookieYear': '',
    'PlayerPosition': '',
    'Outcome': '',
    'Location': '',
    'GameSegment': '',
    'GameId': '',
    'DateTo': '',
    'DateFrom': ''
}


response = requests.get(url_base, params=parameters, headers=headers)
content = json.loads(response.content)

# %%
# transform contents into dataframe
results = content['resultSets'][0]
headers = results['headers']
rows = results['rowSet']
harden18_df = pd.DataFrame(rows)
harden18_df.columns = headers

# %%
harden18_df.head()
# Out:
#            GRID_TYPE     GAME_ID  GAME_EVENT_ID  PLAYER_ID   PLAYER_NAME  \
# 0  Shot Chart Detail  0021800009             11     201935  James Harden
# 1  Shot Chart Detail  0021800009             28     201935  James Harden
# 2  Shot Chart Detail  0021800009             55     201935  James Harden
# 3  Shot Chart Detail  0021800009            103     201935  James Harden
# 4  Shot Chart Detail  0021800009            246     201935  James Harden
#
#       TEAM_ID        TEAM_NAME  PERIOD  MINUTES_REMAINING  SECONDS_REMAINING  \
# 0  1610612745  Houston Rockets       1                 11                 17
# 1  1610612745  Houston Rockets       1                  9                 33
# 2  1610612745  Houston Rockets       1                  7                 51
# 3  1610612745  Houston Rockets       1                  4                 12
# 4  1610612745  Houston Rockets       2                  6                  6
#
#    ...        SHOT_ZONE_AREA  SHOT_ZONE_RANGE SHOT_DISTANCE LOC_X LOC_Y  \
# 0  ...             Center(C)  Less Than 8 ft.             1     3    12
# 1  ...             Center(C)          24+ ft.            27   -61   264
# 2  ...             Center(C)          24+ ft.            25    -1   259
# 3  ...  Left Side Center(LC)          24+ ft.            26  -120   232
# 4  ...             Center(C)  Less Than 8 ft.             2     3    20
#
#   SHOT_ATTEMPTED_FLAG  SHOT_MADE_FLAG  GAME_DATE  HTM  VTM
# 0                   1               0   20181017  HOU  NOP
# 1                   1               0   20181017  HOU  NOP
# 2                   1               0   20181017  HOU  NOP
# 3                   1               1   20181017  HOU  NOP
# 4                   1               1   20181017  HOU  NOP
#
# [5 rows x 24 columns]

# %%
harden18_df["yr_1"] = 2018

# %%
harden18_df["yr_2"] = 2019

# %%
harden18_df["season"] = harden18_df["yr_1"].astype(str) + '-' + harden18_df["yr_2"].astype(str)

# %%
harden18_df.head()
# Out:
#            GRID_TYPE     GAME_ID  GAME_EVENT_ID  PLAYER_ID   PLAYER_NAME  \
# 0  Shot Chart Detail  0021800009             11     201935  James Harden
# 1  Shot Chart Detail  0021800009             28     201935  James Harden
# 2  Shot Chart Detail  0021800009             55     201935  James Harden
# 3  Shot Chart Detail  0021800009            103     201935  James Harden
# 4  Shot Chart Detail  0021800009            246     201935  James Harden
#
#       TEAM_ID        TEAM_NAME  PERIOD  MINUTES_REMAINING  SECONDS_REMAINING  \
# 0  1610612745  Houston Rockets       1                 11                 17
# 1  1610612745  Houston Rockets       1                  9                 33
# 2  1610612745  Houston Rockets       1                  7                 51
# 3  1610612745  Houston Rockets       1                  4                 12
# 4  1610612745  Houston Rockets       2                  6                  6
#
#    ... LOC_X LOC_Y SHOT_ATTEMPTED_FLAG SHOT_MADE_FLAG GAME_DATE  HTM  VTM  \
# 0  ...     3    12                   1              0  20181017  HOU  NOP
# 1  ...   -61   264                   1              0  20181017  HOU  NOP
# 2  ...    -1   259                   1              0  20181017  HOU  NOP
# 3  ...  -120   232                   1              1  20181017  HOU  NOP
# 4  ...     3    20                   1              1  20181017  HOU  NOP
#
#    yr_1  yr_2     season
# 0  2018  2019  2018-2019
# 1  2018  2019  2018-2019
# 2  2018  2019  2018-2019
# 3  2018  2019  2018-2019
# 4  2018  2019  2018-2019
#
# [5 rows x 27 columns]

# %%
harden18_df.to_csv("../shot_data/2018-19.csv", index=False)

# %%
# Jordan, 1996-97
url_base = 'https://stats.nba.com/stats/shotchartdetail'

headers = {
    'Host': 'stats.nba.com',
    'Connection': 'keep-alive',
    'Accept': 'application/json, text/plain, */*',
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/79.0.3945.130 Safari/537.36',
    'Referer': 'https://stats.nba.com/',
    "x-nba-stats-origin": "stats",
    "x-nba-stats-token": "true",
    'Accept-Encoding': 'gzip, deflate, br',
    'Accept-Language': 'en-US,en;q=0.9',
}

# %%
parameters = {
    'ContextMeasure': 'FGA',
    'LastNGames': 0,
    'LeagueID': '00',
    'Month': 0,
    'OpponentTeamID': 0,
    'Period': 0,
    'PlayerID': 893,
    'SeasonType': 'Regular Season',
    'TeamID': 0,
    'VsDivision': '',
    'VsConference': '',
    'SeasonSegment': '',
    'Season': '1996-97',
    'RookieYear': '',
    'PlayerPosition': '',
    'Outcome': '',
    'Location': '',
    'GameSegment': '',
    'GameId': '',
    'DateTo': '',
    'DateFrom': ''
}


response = requests.get(url_base, params=parameters, headers=headers)
content = json.loads(response.content)

# %%
# transform contents into dataframe
results = content['resultSets'][0]
headers = results['headers']
rows = results['rowSet']
jordan96_df = pd.DataFrame(rows)
jordan96_df.columns = headers

# %%
jordan96_df["yr_1"] = 1996
jordan96_df["yr_2"] = 1997

# %%
jordan96_df["season"] = jordan96_df["yr_1"].astype(str) + '-' + jordan96_df["yr_2"].astype(str)

# %%
jordan96_df.head()
# Out:
#            GRID_TYPE     GAME_ID  GAME_EVENT_ID  PLAYER_ID     PLAYER_NAME  \
# 0  Shot Chart Detail  0029600001             43        893  Michael Jordan
# 1  Shot Chart Detail  0029600001             38        893  Michael Jordan
# 2  Shot Chart Detail  0029600001             57        893  Michael Jordan
# 3  Shot Chart Detail  0029600001             65        893  Michael Jordan
# 4  Shot Chart Detail  0029600001             78        893  Michael Jordan
#
#       TEAM_ID      TEAM_NAME  PERIOD  MINUTES_REMAINING  SECONDS_REMAINING  \
# 0  1610612741  Chicago Bulls       1                 11                  6
# 1  1610612741  Chicago Bulls       1                  7                  1
# 2  1610612741  Chicago Bulls       1                  5                  0
# 3  1610612741  Chicago Bulls       1                  3                 53
# 4  1610612741  Chicago Bulls       1                  2                 29
#
#    ...        SHOT_ZONE_AREA SHOT_ZONE_RANGE SHOT_DISTANCE LOC_X LOC_Y  \
# 0  ...             Center(C)        8-16 ft.            15    45   148
# 1  ...          Left Side(L)         24+ ft.            24  -231    86
# 2  ...         Right Side(R)        8-16 ft.            15   114   108
# 3  ...  Left Side Center(LC)       16-24 ft.            17  -133   110
# 4  ...         Right Side(R)         24+ ft.            23   233    -1
#
#   SHOT_ATTEMPTED_FLAG  SHOT_MADE_FLAG  GAME_DATE  HTM  VTM
# 0                   1               0   19961101  BOS  CHI
# 1                   1               0   19961101  BOS  CHI
# 2                   1               1   19961101  BOS  CHI
# 3                   1               1   19961101  BOS  CHI
# 4                   1               0   19961101  BOS  CHI
#
# [5 rows x 24 columns]

# %%
jordan96_df.to_csv("../shot_data/1996-97.csv", index=False)

# %%
# Jordan, 1997-98
url_base = 'https://stats.nba.com/stats/shotchartdetail'

headers = {
    'Host': 'stats.nba.com',
    'Connection': 'keep-alive',
    'Accept': 'application/json, text/plain, */*',
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/79.0.3945.130 Safari/537.36',
    'Referer': 'https://stats.nba.com/',
    "x-nba-stats-origin": "stats",
    "x-nba-stats-token": "true",
    'Accept-Encoding': 'gzip, deflate, br',
    'Accept-Language': 'en-US,en;q=0.9',
}

parameters = {
    'ContextMeasure': 'FGA',
    'LastNGames': 0,
    'LeagueID': '00',
    'Month': 0,
    'OpponentTeamID': 0,
    'Period': 0,
    'PlayerID': 893,
    'SeasonType': 'Regular Season',
    'TeamID': 0,
    'VsDivision': '',
    'VsConference': '',
    'SeasonSegment': '',
    'Season': '1997-98',
    'RookieYear': '',
    'PlayerPosition': '',
    'Outcome': '',
    'Location': '',
    'GameSegment': '',
    'GameId': '',
    'DateTo': '',
    'DateFrom': ''
}


response = requests.get(url_base, params=parameters, headers=headers)
content = json.loads(response.content)

# %%
results = content['resultSets'][0]
headers = results['headers']
rows = results['rowSet']
jordan97_df = pd.DataFrame(rows)
jordan97_df.columns = headers
jordan97_df.head()
# Out:
#            GRID_TYPE     GAME_ID  GAME_EVENT_ID  PLAYER_ID     PLAYER_NAME  \
# 0  Shot Chart Detail  0029700001             54        893  Michael Jordan
# 1  Shot Chart Detail  0029700001             66        893  Michael Jordan
# 2  Shot Chart Detail  0029700001             78        893  Michael Jordan
# 3  Shot Chart Detail  0029700001            178        893  Michael Jordan
# 4  Shot Chart Detail  0029700001            180        893  Michael Jordan
#
#       TEAM_ID      TEAM_NAME  PERIOD  MINUTES_REMAINING  SECONDS_REMAINING  \
# 0  1610612741  Chicago Bulls       1                  6                  7
# 1  1610612741  Chicago Bulls       1                  5                 25
# 2  1610612741  Chicago Bulls       1                  4                 16
# 3  1610612741  Chicago Bulls       2                  6                 51
# 4  1610612741  Chicago Bulls       2                  6                 43
#
#    ...        SHOT_ZONE_AREA  SHOT_ZONE_RANGE SHOT_DISTANCE LOC_X LOC_Y  \
# 0  ...  Left Side Center(LC)        16-24 ft.            21   -85   199
# 1  ...             Center(C)  Less Than 8 ft.             0     0     0
# 2  ...             Center(C)  Less Than 8 ft.             0     0     0
# 3  ...             Center(C)  Less Than 8 ft.             1   -16    -1
# 4  ...          Left Side(L)        16-24 ft.            17  -156    74
#
#   SHOT_ATTEMPTED_FLAG  SHOT_MADE_FLAG  GAME_DATE  HTM  VTM
# 0                   1               0   19971031  BOS  CHI
# 1                   1               1   19971031  BOS  CHI
# 2                   1               1   19971031  BOS  CHI
# 3                   1               1   19971031  BOS  CHI
# 4                   1               0   19971031  BOS  CHI
#
# [5 rows x 24 columns]

# %%
jordan97_df.to_csv("../shot_data/1997-98.csv", index=False)

# %%
# Shaq, 1998-99
url_base = 'https://stats.nba.com/stats/shotchartdetail'

headers = {
    'Host': 'stats.nba.com',
    'Connection': 'keep-alive',
    'Accept': 'application/json, text/plain, */*',
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/79.0.3945.130 Safari/537.36',
    'Referer': 'https://stats.nba.com/',
    "x-nba-stats-origin": "stats",
    "x-nba-stats-token": "true",
    'Accept-Encoding': 'gzip, deflate, br',
    'Accept-Language': 'en-US,en;q=0.9',
}

parameters = {
    'ContextMeasure': 'FGA',
    'LastNGames': 0,
    'LeagueID': '00',
    'Month': 0,
    'OpponentTeamID': 0,
    'Period': 0,
    'PlayerID': 406,
    'SeasonType': 'Regular Season',
    'TeamID': 0,
    'VsDivision': '',
    'VsConference': '',
    'SeasonSegment': '',
    'Season': '1998-99',
    'RookieYear': '',
    'PlayerPosition': '',
    'Outcome': '',
    'Location': '',
    'GameSegment': '',
    'GameId': '',
    'DateTo': '',
    'DateFrom': ''
}


response = requests.get(url_base, params=parameters, headers=headers)
content = json.loads(response.content)

# %%
results = content['resultSets'][0]
headers = results['headers']
rows = results['rowSet']
shaq98_df = pd.DataFrame(rows)
shaq98_df.columns = headers
shaq98_df.head()
# Out:
#            GRID_TYPE     GAME_ID  GAME_EVENT_ID  PLAYER_ID       PLAYER_NAME  \
# 0  Shot Chart Detail  0029800011              5        406  Shaquille O'Neal
# 1  Shot Chart Detail  0029800011              6        406  Shaquille O'Neal
# 2  Shot Chart Detail  0029800011             18        406  Shaquille O'Neal
# 3  Shot Chart Detail  0029800011             31        406  Shaquille O'Neal
# 4  Shot Chart Detail  0029800011            159        406  Shaquille O'Neal
#
#       TEAM_ID           TEAM_NAME  PERIOD  MINUTES_REMAINING  \
# 0  1610612747  Los Angeles Lakers       1                 11
# 1  1610612747  Los Angeles Lakers       1                 11
# 2  1610612747  Los Angeles Lakers       1                 10
# 3  1610612747  Los Angeles Lakers       1                  8
# 4  1610612747  Los Angeles Lakers       2                  9
#
#    SECONDS_REMAINING  ... SHOT_ZONE_AREA  SHOT_ZONE_RANGE SHOT_DISTANCE LOC_X  \
# 0                 31  ...      Center(C)  Less Than 8 ft.             0     0
# 1                 29  ...      Center(C)  Less Than 8 ft.             0     0
# 2                 15  ...      Center(C)  Less Than 8 ft.             0     0
# 3                 33  ...   Left Side(L)         8-16 ft.            11   -70
# 4                 42  ...      Center(C)  Less Than 8 ft.             6    55
#
#   LOC_Y SHOT_ATTEMPTED_FLAG  SHOT_MADE_FLAG  GAME_DATE  HTM  VTM
# 0     0                   1               0   19990205  LAL  HOU
# 1     0                   1               0   19990205  LAL  HOU
# 2     0                   1               1   19990205  LAL  HOU
# 3    93                   1               1   19990205  LAL  HOU
# 4    33                   1               1   19990205  LAL  HOU
#
# [5 rows x 24 columns]

# %%
shaq98_df.to_csv("../shot_data/1998-99.csv", index=False)

# %%
# Stackhouse, 2000-01
url_base = 'https://stats.nba.com/stats/shotchartdetail'

headers = {
    'Host': 'stats.nba.com',
    'Connection': 'keep-alive',
    'Accept': 'application/json, text/plain, */*',
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/79.0.3945.130 Safari/537.36',
    'Referer': 'https://stats.nba.com/',
    "x-nba-stats-origin": "stats",
    "x-nba-stats-token": "true",
    'Accept-Encoding': 'gzip, deflate, br',
    'Accept-Language': 'en-US,en;q=0.9',
}

parameters = {
    'ContextMeasure': 'FGA',
    'LastNGames': 0,
    'LeagueID': '00',
    'Month': 0,
    'OpponentTeamID': 0,
    'Period': 0,
    'PlayerID': 711,
    'SeasonType': 'Regular Season',
    'TeamID': 0,
    'VsDivision': '',
    'VsConference': '',
    'SeasonSegment': '',
    'Season': '2000-01',
    'RookieYear': '',
    'PlayerPosition': '',
    'Outcome': '',
    'Location': '',
    'GameSegment': '',
    'GameId': '',
    'DateTo': '',
    'DateFrom': ''
}

response = requests.get(url_base, params=parameters, headers=headers)
content = json.loads(response.content)

# %%
results = content['resultSets'][0]
headers = results['headers']
rows = results['rowSet']
stack00_df = pd.DataFrame(rows)
stack00_df.columns = headers
stack00_df.head()
# Out:
#            GRID_TYPE     GAME_ID  GAME_EVENT_ID  PLAYER_ID       PLAYER_NAME  \
# 0  Shot Chart Detail  0020000005              9        711  Jerry Stackhouse
# 1  Shot Chart Detail  0020000005             15        711  Jerry Stackhouse
# 2  Shot Chart Detail  0020000005             18        711  Jerry Stackhouse
# 3  Shot Chart Detail  0020000005             26        711  Jerry Stackhouse
# 4  Shot Chart Detail  0020000005             30        711  Jerry Stackhouse
#
#       TEAM_ID        TEAM_NAME  PERIOD  MINUTES_REMAINING  SECONDS_REMAINING  \
# 0  1610612765  Detroit Pistons       1                 11                 23
# 1  1610612765  Detroit Pistons       1                 10                 47
# 2  1610612765  Detroit Pistons       1                 10                 37
# 3  1610612765  Detroit Pistons       1                  9                 46
# 4  1610612765  Detroit Pistons       1                  9                 31
#
#    ... SHOT_ZONE_AREA  SHOT_ZONE_RANGE SHOT_DISTANCE LOC_X LOC_Y  \
# 0  ...      Center(C)  Less Than 8 ft.             0     0     0
# 1  ...      Center(C)  Less Than 8 ft.             0     0     0
# 2  ...  Right Side(R)         8-16 ft.            15   159     0
# 3  ...  Right Side(R)        16-24 ft.            16   167     4
# 4  ...  Right Side(R)        16-24 ft.            18   188     0
#
#   SHOT_ATTEMPTED_FLAG  SHOT_MADE_FLAG  GAME_DATE  HTM  VTM
# 0                   1               1   20001031  TOR  DET
# 1                   1               0   20001031  TOR  DET
# 2                   1               0   20001031  TOR  DET
# 3                   1               0   20001031  TOR  DET
# 4                   1               0   20001031  TOR  DET
#
# [5 rows x 24 columns]

# %%
stack00_df.to_csv("../shot_data/2000-01.csv", index=False)

# %%
# Pierce, 
url_base = 'https://stats.nba.com/stats/shotchartdetail'

headers = {
    'Host': 'stats.nba.com',
    'Connection': 'keep-alive',
    'Accept': 'application/json, text/plain, */*',
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/79.0.3945.130 Safari/537.36',
    'Referer': 'https://stats.nba.com/',
    "x-nba-stats-origin": "stats",
    "x-nba-stats-token": "true",
    'Accept-Encoding': 'gzip, deflate, br',
    'Accept-Language': 'en-US,en;q=0.9',
}

parameters = {
    'ContextMeasure': 'FGA',
    'LastNGames': 0,
    'LeagueID': '00',
    'Month': 0,
    'OpponentTeamID': 0,
    'Period': 0,
    'PlayerID': 1718,
    'SeasonType': 'Regular Season',
    'TeamID': 0,
    'VsDivision': '',
    'VsConference': '',
    'SeasonSegment': '',
    'Season': '2001-02',
    'RookieYear': '',
    'PlayerPosition': '',
    'Outcome': '',
    'Location': '',
    'GameSegment': '',
    'GameId': '',
    'DateTo': '',
    'DateFrom': ''
}

response = requests.get(url_base, params=parameters, headers=headers)
content = json.loads(response.content)

results = content['resultSets'][0]
headers = results['headers']
rows = results['rowSet']
pierce02_df = pd.DataFrame(rows)
pierce02_df.columns = headers
pierce02_df.head()
# Out:
#            GRID_TYPE     GAME_ID  GAME_EVENT_ID  PLAYER_ID  PLAYER_NAME  \
# 0  Shot Chart Detail  0020100001             13       1718  Paul Pierce
# 1  Shot Chart Detail  0020100001             27       1718  Paul Pierce
# 2  Shot Chart Detail  0020100001             35       1718  Paul Pierce
# 3  Shot Chart Detail  0020100001             66       1718  Paul Pierce
# 4  Shot Chart Detail  0020100001             68       1718  Paul Pierce
#
#       TEAM_ID       TEAM_NAME  PERIOD  MINUTES_REMAINING  SECONDS_REMAINING  \
# 0  1610612738  Boston Celtics       1                 10                 31
# 1  1610612738  Boston Celtics       1                  9                  4
# 2  1610612738  Boston Celtics       1                  8                 30
# 3  1610612738  Boston Celtics       1                  5                 30
# 4  1610612738  Boston Celtics       1                  4                 55
#
#    ...        SHOT_ZONE_AREA  SHOT_ZONE_RANGE SHOT_DISTANCE LOC_X LOC_Y  \
# 0  ...          Left Side(L)         8-16 ft.            14  -132    51
# 1  ...             Center(C)  Less Than 8 ft.             7    70    17
# 2  ...         Right Side(R)          24+ ft.            23   235     0
# 3  ...          Left Side(L)         8-16 ft.            14  -124    76
# 4  ...  Left Side Center(LC)        16-24 ft.            18  -147   120
#
#   SHOT_ATTEMPTED_FLAG  SHOT_MADE_FLAG  GAME_DATE  HTM  VTM
# 0                   1               1   20011030  CLE  BOS
# 1                   1               0   20011030  CLE  BOS
# 2                   1               0   20011030  CLE  BOS
# 3                   1               1   20011030  CLE  BOS
# 4                   1               1   20011030  CLE  BOS
#
# [5 rows x 24 columns]

# %%
pierce02_df.to_csv("../shot_data/2001-02.csv", index=False)

# %%
# Kobe, 2002-03
url_base = 'https://stats.nba.com/stats/shotchartdetail'

headers = {
    'Host': 'stats.nba.com',
    'Connection': 'keep-alive',
    'Accept': 'application/json, text/plain, */*',
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/79.0.3945.130 Safari/537.36',
    'Referer': 'https://stats.nba.com/',
    "x-nba-stats-origin": "stats",
    "x-nba-stats-token": "true",
    'Accept-Encoding': 'gzip, deflate, br',
    'Accept-Language': 'en-US,en;q=0.9',
}

parameters = {
    'ContextMeasure': 'FGA',
    'LastNGames': 0,
    'LeagueID': '00',
    'Month': 0,
    'OpponentTeamID': 0,
    'Period': 0,
    'PlayerID': 977,
    'SeasonType': 'Regular Season',
    'TeamID': 0,
    'VsDivision': '',
    'VsConference': '',
    'SeasonSegment': '',
    'Season': '2002-03',
    'RookieYear': '',
    'PlayerPosition': '',
    'Outcome': '',
    'Location': '',
    'GameSegment': '',
    'GameId': '',
    'DateTo': '',
    'DateFrom': ''
}

response = requests.get(url_base, params=parameters, headers=headers)
content = json.loads(response.content)

results = content['resultSets'][0]
headers = results['headers']
rows = results['rowSet']
kobe02_df = pd.DataFrame(rows)
kobe02_df.columns = headers
kobe02_df.head()
# Out:
#            GRID_TYPE     GAME_ID  GAME_EVENT_ID  PLAYER_ID  PLAYER_NAME  \
# 0  Shot Chart Detail  0020200003              7        977  Kobe Bryant
# 1  Shot Chart Detail  0020200003             11        977  Kobe Bryant
# 2  Shot Chart Detail  0020200003             17        977  Kobe Bryant
# 3  Shot Chart Detail  0020200003             19        977  Kobe Bryant
# 4  Shot Chart Detail  0020200003             54        977  Kobe Bryant
#
#       TEAM_ID           TEAM_NAME  PERIOD  MINUTES_REMAINING  \
# 0  1610612747  Los Angeles Lakers       1                 11
# 1  1610612747  Los Angeles Lakers       1                 10
# 2  1610612747  Los Angeles Lakers       1                 10
# 3  1610612747  Los Angeles Lakers       1                 10
# 4  1610612747  Los Angeles Lakers       1                  5
#
#    SECONDS_REMAINING  ... SHOT_ZONE_AREA  SHOT_ZONE_RANGE SHOT_DISTANCE LOC_X  \
# 0                 27  ...   Left Side(L)         8-16 ft.            15  -117
# 1                 57  ...   Left Side(L)         8-16 ft.            14  -120
# 2                 18  ...      Center(C)         8-16 ft.             8    41
# 3                 12  ...      Center(C)  Less Than 8 ft.             0     0
# 4                 55  ...      Center(C)  Less Than 8 ft.             6    38
#
#   LOC_Y SHOT_ATTEMPTED_FLAG  SHOT_MADE_FLAG  GAME_DATE  HTM  VTM
# 0   105                   1               0   20021029  LAL  SAS
# 1    89                   1               1   20021029  LAL  SAS
# 2    77                   1               0   20021029  LAL  SAS
# 3     0                   1               0   20021029  LAL  SAS
# 4    51                   1               0   20021029  LAL  SAS
#
# [5 rows x 24 columns]

# %%
kobe02_df.to_csv("../shot_data/2002-03.csv", index=False)

# %%
# Garnett, 2003-04
url_base = 'https://stats.nba.com/stats/shotchartdetail'

headers = {
    'Host': 'stats.nba.com',
    'Connection': 'keep-alive',
    'Accept': 'application/json, text/plain, */*',
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/79.0.3945.130 Safari/537.36',
    'Referer': 'https://stats.nba.com/',
    "x-nba-stats-origin": "stats",
    "x-nba-stats-token": "true",
    'Accept-Encoding': 'gzip, deflate, br',
    'Accept-Language': 'en-US,en;q=0.9',
}

parameters = {
    'ContextMeasure': 'FGA',
    'LastNGames': 0,
    'LeagueID': '00',
    'Month': 0,
    'OpponentTeamID': 0,
    'Period': 0,
    'PlayerID': 708,
    'SeasonType': 'Regular Season',
    'TeamID': 0,
    'VsDivision': '',
    'VsConference': '',
    'SeasonSegment': '',
    'Season': '2003-04',
    'RookieYear': '',
    'PlayerPosition': '',
    'Outcome': '',
    'Location': '',
    'GameSegment': '',
    'GameId': '',
    'DateTo': '',
    'DateFrom': ''
}

response = requests.get(url_base, params=parameters, headers=headers)
content = json.loads(response.content)

results = content['resultSets'][0]
headers = results['headers']
rows = results['rowSet']
kg03_df = pd.DataFrame(rows)
kg03_df.columns = headers
kg03_df.head()
# Out:
#            GRID_TYPE     GAME_ID  GAME_EVENT_ID  PLAYER_ID    PLAYER_NAME  \
# 0  Shot Chart Detail  0020300009              8        708  Kevin Garnett
# 1  Shot Chart Detail  0020300009             10        708  Kevin Garnett
# 2  Shot Chart Detail  0020300009             14        708  Kevin Garnett
# 3  Shot Chart Detail  0020300009             18        708  Kevin Garnett
# 4  Shot Chart Detail  0020300009             30        708  Kevin Garnett
#
#       TEAM_ID               TEAM_NAME  PERIOD  MINUTES_REMAINING  \
# 0  1610612750  Minnesota Timberwolves       1                 11
# 1  1610612750  Minnesota Timberwolves       1                 10
# 2  1610612750  Minnesota Timberwolves       1                 10
# 3  1610612750  Minnesota Timberwolves       1                  9
# 4  1610612750  Minnesota Timberwolves       1                  7
#
#    SECONDS_REMAINING  ... SHOT_ZONE_AREA  SHOT_ZONE_RANGE SHOT_DISTANCE LOC_X  \
# 0                 14  ...      Center(C)  Less Than 8 ft.             0     0
# 1                 34  ...   Left Side(L)         8-16 ft.            12  -120
# 2                  9  ...      Center(C)  Less Than 8 ft.             6    61
# 3                 53  ...      Center(C)  Less Than 8 ft.             0     0
# 4                 53  ...      Center(C)  Less Than 8 ft.             7    59
#
#   LOC_Y SHOT_ATTEMPTED_FLAG  SHOT_MADE_FLAG  GAME_DATE  HTM  VTM
# 0     0                   1               1   20031029  MIN  MIL
# 1    -3                   1               0   20031029  MIN  MIL
# 2    23                   1               0   20031029  MIN  MIL
# 3     0                   1               1   20031029  MIN  MIL
# 4    40                   1               1   20031029  MIN  MIL
#
# [5 rows x 24 columns]

# %%
kg03_df.to_csv("../shot_data/2003-04.csv", index=False)

# %%
# Iverson, 2004-05
url_base = 'https://stats.nba.com/stats/shotchartdetail'

headers = {
    'Host': 'stats.nba.com',
    'Connection': 'keep-alive',
    'Accept': 'application/json, text/plain, */*',
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/79.0.3945.130 Safari/537.36',
    'Referer': 'https://stats.nba.com/',
    "x-nba-stats-origin": "stats",
    "x-nba-stats-token": "true",
    'Accept-Encoding': 'gzip, deflate, br',
    'Accept-Language': 'en-US,en;q=0.9',
}

parameters = {
    'ContextMeasure': 'FGA',
    'LastNGames': 0,
    'LeagueID': '00',
    'Month': 0,
    'OpponentTeamID': 0,
    'Period': 0,
    'PlayerID': 947,
    'SeasonType': 'Regular Season',
    'TeamID': 0,
    'VsDivision': '',
    'VsConference': '',
    'SeasonSegment': '',
    'Season': '2004-05',
    'RookieYear': '',
    'PlayerPosition': '',
    'Outcome': '',
    'Location': '',
    'GameSegment': '',
    'GameId': '',
    'DateTo': '',
    'DateFrom': ''
}

response = requests.get(url_base, params=parameters, headers=headers)
content = json.loads(response.content)

results = content['resultSets'][0]
headers = results['headers']
rows = results['rowSet']
iverson04_df = pd.DataFrame(rows)
iverson04_df.columns = headers
iverson04_df.to_csv("../shot_data/2004-05.csv", index=False)

# %%
# Kobe, 2005-06
url_base = 'https://stats.nba.com/stats/shotchartdetail'

headers = {
    'Host': 'stats.nba.com',
    'Connection': 'keep-alive',
    'Accept': 'application/json, text/plain, */*',
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/79.0.3945.130 Safari/537.36',
    'Referer': 'https://stats.nba.com/',
    "x-nba-stats-origin": "stats",
    "x-nba-stats-token": "true",
    'Accept-Encoding': 'gzip, deflate, br',
    'Accept-Language': 'en-US,en;q=0.9',
}

parameters = {
    'ContextMeasure': 'FGA',
    'LastNGames': 0,
    'LeagueID': '00',
    'Month': 0,
    'OpponentTeamID': 0,
    'Period': 0,
    'PlayerID': 977,
    'SeasonType': 'Regular Season',
    'TeamID': 0,
    'VsDivision': '',
    'VsConference': '',
    'SeasonSegment': '',
    'Season': '2005-06',
    'RookieYear': '',
    'PlayerPosition': '',
    'Outcome': '',
    'Location': '',
    'GameSegment': '',
    'GameId': '',
    'DateTo': '',
    'DateFrom': ''
}

response = requests.get(url_base, params=parameters, headers=headers)
content = json.loads(response.content)

results = content['resultSets'][0]
headers = results['headers']
rows = results['rowSet']
kobe05_df = pd.DataFrame(rows)
kobe05_df.columns = headers
kobe05_df.to_csv("../shot_data/2005-06.csv", index=False)

# %%
# Kobe, 2006-07
url_base = 'https://stats.nba.com/stats/shotchartdetail'

headers = {
    'Host': 'stats.nba.com',
    'Connection': 'keep-alive',
    'Accept': 'application/json, text/plain, */*',
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/79.0.3945.130 Safari/537.36',
    'Referer': 'https://stats.nba.com/',
    "x-nba-stats-origin": "stats",
    "x-nba-stats-token": "true",
    'Accept-Encoding': 'gzip, deflate, br',
    'Accept-Language': 'en-US,en;q=0.9',
}

parameters = {
    'ContextMeasure': 'FGA',
    'LastNGames': 0,
    'LeagueID': '00',
    'Month': 0,
    'OpponentTeamID': 0,
    'Period': 0,
    'PlayerID': 977,
    'SeasonType': 'Regular Season',
    'TeamID': 0,
    'VsDivision': '',
    'VsConference': '',
    'SeasonSegment': '',
    'Season': '2006-07',
    'RookieYear': '',
    'PlayerPosition': '',
    'Outcome': '',
    'Location': '',
    'GameSegment': '',
    'GameId': '',
    'DateTo': '',
    'DateFrom': ''
}

response = requests.get(url_base, params=parameters, headers=headers)
content = json.loads(response.content)

results = content['resultSets'][0]
headers = results['headers']
rows = results['rowSet']
kobe06_df = pd.DataFrame(rows)
kobe06_df.columns = headers
kobe06_df.to_csv("../shot_data/2006-07.csv", index=False)

# %%
# Kobe, 2007-08
url_base = 'https://stats.nba.com/stats/shotchartdetail'

headers = {
    'Host': 'stats.nba.com',
    'Connection': 'keep-alive',
    'Accept': 'application/json, text/plain, */*',
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/79.0.3945.130 Safari/537.36',
    'Referer': 'https://stats.nba.com/',
    "x-nba-stats-origin": "stats",
    "x-nba-stats-token": "true",
    'Accept-Encoding': 'gzip, deflate, br',
    'Accept-Language': 'en-US,en;q=0.9',
}

parameters = {
    'ContextMeasure': 'FGA',
    'LastNGames': 0,
    'LeagueID': '00',
    'Month': 0,
    'OpponentTeamID': 0,
    'Period': 0,
    'PlayerID': 977,
    'SeasonType': 'Regular Season',
    'TeamID': 0,
    'VsDivision': '',
    'VsConference': '',
    'SeasonSegment': '',
    'Season': '2007-08',
    'RookieYear': '',
    'PlayerPosition': '',
    'Outcome': '',
    'Location': '',
    'GameSegment': '',
    'GameId': '',
    'DateTo': '',
    'DateFrom': ''
}

response = requests.get(url_base, params=parameters, headers=headers)
content = json.loads(response.content)

results = content['resultSets'][0]
headers = results['headers']
rows = results['rowSet']
kobe07_df = pd.DataFrame(rows)
kobe07_df.columns = headers
kobe07_df.to_csv("../shot_data/2007-08.csv", index=False)

# %%
# Wade, 2008-09
url_base = 'https://stats.nba.com/stats/shotchartdetail'

headers = {
    'Host': 'stats.nba.com',
    'Connection': 'keep-alive',
    'Accept': 'application/json, text/plain, */*',
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/79.0.3945.130 Safari/537.36',
    'Referer': 'https://stats.nba.com/',
    "x-nba-stats-origin": "stats",
    "x-nba-stats-token": "true",
    'Accept-Encoding': 'gzip, deflate, br',
    'Accept-Language': 'en-US,en;q=0.9',
}

parameters = {
    'ContextMeasure': 'FGA',
    'LastNGames': 0,
    'LeagueID': '00',
    'Month': 0,
    'OpponentTeamID': 0,
    'Period': 0,
    'PlayerID': 2548,
    'SeasonType': 'Regular Season',
    'TeamID': 0,
    'VsDivision': '',
    'VsConference': '',
    'SeasonSegment': '',
    'Season': '2008-09',
    'RookieYear': '',
    'PlayerPosition': '',
    'Outcome': '',
    'Location': '',
    'GameSegment': '',
    'GameId': '',
    'DateTo': '',
    'DateFrom': ''
}

response = requests.get(url_base, params=parameters, headers=headers)
content = json.loads(response.content)

results = content['resultSets'][0]
headers = results['headers']
rows = results['rowSet']
wade08_df = pd.DataFrame(rows)
wade08_df.columns = headers
wade08_df.to_csv("../shot_data/2008-09.csv", index=False)

# %%
# Durant, 2009-10
url_base = 'https://stats.nba.com/stats/shotchartdetail'

headers = {
    'Host': 'stats.nba.com',
    'Connection': 'keep-alive',
    'Accept': 'application/json, text/plain, */*',
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/79.0.3945.130 Safari/537.36',
    'Referer': 'https://stats.nba.com/',
    "x-nba-stats-origin": "stats",
    "x-nba-stats-token": "true",
    'Accept-Encoding': 'gzip, deflate, br',
    'Accept-Language': 'en-US,en;q=0.9',
}

parameters = {
    'ContextMeasure': 'FGA',
    'LastNGames': 0,
    'LeagueID': '00',
    'Month': 0,
    'OpponentTeamID': 0,
    'Period': 0,
    'PlayerID': 201142,
    'SeasonType': 'Regular Season',
    'TeamID': 0,
    'VsDivision': '',
    'VsConference': '',
    'SeasonSegment': '',
    'Season': '2009-10',
    'RookieYear': '',
    'PlayerPosition': '',
    'Outcome': '',
    'Location': '',
    'GameSegment': '',
    'GameId': '',
    'DateTo': '',
    'DateFrom': ''
}

response = requests.get(url_base, params=parameters, headers=headers)
content = json.loads(response.content)

results = content['resultSets'][0]
headers = results['headers']
rows = results['rowSet']
durant09_df = pd.DataFrame(rows)
durant09_df.columns = headers
durant09_df.to_csv("../shot_data/2009-10.csv", index=False)

# %%
# Durant, 2010-11
url_base = 'https://stats.nba.com/stats/shotchartdetail'

headers = {
    'Host': 'stats.nba.com',
    'Connection': 'keep-alive',
    'Accept': 'application/json, text/plain, */*',
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/79.0.3945.130 Safari/537.36',
    'Referer': 'https://stats.nba.com/',
    "x-nba-stats-origin": "stats",
    "x-nba-stats-token": "true",
    'Accept-Encoding': 'gzip, deflate, br',
    'Accept-Language': 'en-US,en;q=0.9',
}

parameters = {
    'ContextMeasure': 'FGA',
    'LastNGames': 0,
    'LeagueID': '00',
    'Month': 0,
    'OpponentTeamID': 0,
    'Period': 0,
    'PlayerID': 201142,
    'SeasonType': 'Regular Season',
    'TeamID': 0,
    'VsDivision': '',
    'VsConference': '',
    'SeasonSegment': '',
    'Season': '2010-11',
    'RookieYear': '',
    'PlayerPosition': '',
    'Outcome': '',
    'Location': '',
    'GameSegment': '',
    'GameId': '',
    'DateTo': '',
    'DateFrom': ''
}

response = requests.get(url_base, params=parameters, headers=headers)
content = json.loads(response.content)

results = content['resultSets'][0]
headers = results['headers']
rows = results['rowSet']
durant10_df = pd.DataFrame(rows)
durant10_df.columns = headers
durant10_df.to_csv("../shot_data/2010-11.csv", index=False)

# %%
# Durant, 2011-12
url_base = 'https://stats.nba.com/stats/shotchartdetail'

headers = {
    'Host': 'stats.nba.com',
    'Connection': 'keep-alive',
    'Accept': 'application/json, text/plain, */*',
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/79.0.3945.130 Safari/537.36',
    'Referer': 'https://stats.nba.com/',
    "x-nba-stats-origin": "stats",
    "x-nba-stats-token": "true",
    'Accept-Encoding': 'gzip, deflate, br',
    'Accept-Language': 'en-US,en;q=0.9',
}

parameters = {
    'ContextMeasure': 'FGA',
    'LastNGames': 0,
    'LeagueID': '00',
    'Month': 0,
    'OpponentTeamID': 0,
    'Period': 0,
    'PlayerID': 201142,
    'SeasonType': 'Regular Season',
    'TeamID': 0,
    'VsDivision': '',
    'VsConference': '',
    'SeasonSegment': '',
    'Season': '2011-12',
    'RookieYear': '',
    'PlayerPosition': '',
    'Outcome': '',
    'Location': '',
    'GameSegment': '',
    'GameId': '',
    'DateTo': '',
    'DateFrom': ''
}

response = requests.get(url_base, params=parameters, headers=headers)
content = json.loads(response.content)

results = content['resultSets'][0]
headers = results['headers']
rows = results['rowSet']
durant11_df = pd.DataFrame(rows)
durant11_df.columns = headers
durant11_df.to_csv("../shot_data/2011-12.csv", index=False)

# %%
# Durant, 2012-13
url_base = 'https://stats.nba.com/stats/shotchartdetail'

headers = {
    'Host': 'stats.nba.com',
    'Connection': 'keep-alive',
    'Accept': 'application/json, text/plain, */*',
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/79.0.3945.130 Safari/537.36',
    'Referer': 'https://stats.nba.com/',
    "x-nba-stats-origin": "stats",
    "x-nba-stats-token": "true",
    'Accept-Encoding': 'gzip, deflate, br',
    'Accept-Language': 'en-US,en;q=0.9',
}

parameters = {
    'ContextMeasure': 'FGA',
    'LastNGames': 0,
    'LeagueID': '00',
    'Month': 0,
    'OpponentTeamID': 0,
    'Period': 0,
    'PlayerID': 201142,
    'SeasonType': 'Regular Season',
    'TeamID': 0,
    'VsDivision': '',
    'VsConference': '',
    'SeasonSegment': '',
    'Season': '2012-13',
    'RookieYear': '',
    'PlayerPosition': '',
    'Outcome': '',
    'Location': '',
    'GameSegment': '',
    'GameId': '',
    'DateTo': '',
    'DateFrom': ''
}

response = requests.get(url_base, params=parameters, headers=headers)
content = json.loads(response.content)

results = content['resultSets'][0]
headers = results['headers']
rows = results['rowSet']
durant12_df = pd.DataFrame(rows)
durant12_df.columns = headers
durant12_df.to_csv("../shot_data/2012-13.csv", index=False)

# %%
# Durant, 2013-14
url_base = 'https://stats.nba.com/stats/shotchartdetail'

headers = {
    'Host': 'stats.nba.com',
    'Connection': 'keep-alive',
    'Accept': 'application/json, text/plain, */*',
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/79.0.3945.130 Safari/537.36',
    'Referer': 'https://stats.nba.com/',
    "x-nba-stats-origin": "stats",
    "x-nba-stats-token": "true",
    'Accept-Encoding': 'gzip, deflate, br',
    'Accept-Language': 'en-US,en;q=0.9',
}

parameters = {
    'ContextMeasure': 'FGA',
    'LastNGames': 0,
    'LeagueID': '00',
    'Month': 0,
    'OpponentTeamID': 0,
    'Period': 0,
    'PlayerID': 201142,
    'SeasonType': 'Regular Season',
    'TeamID': 0,
    'VsDivision': '',
    'VsConference': '',
    'SeasonSegment': '',
    'Season': '2013-14',
    'RookieYear': '',
    'PlayerPosition': '',
    'Outcome': '',
    'Location': '',
    'GameSegment': '',
    'GameId': '',
    'DateTo': '',
    'DateFrom': ''
}

response = requests.get(url_base, params=parameters, headers=headers)
content = json.loads(response.content)

results = content['resultSets'][0]
headers = results['headers']
rows = results['rowSet']
durant13_df = pd.DataFrame(rows)
durant13_df.columns = headers
durant13_df.to_csv("../shot_data/2013-14.csv", index=False)
